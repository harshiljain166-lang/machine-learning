# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("whenamancodes/credit-card-customers-prediction")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'credit-card-customers-prediction' dataset.
# Path to dataset files: /kaggle/input/credit-card-customers-prediction

# %%
import os

# List the contents of the downloaded directory
print(os.listdir(path))
# Out:
# ['BankChurners.csv']

# %%
import pandas as pd

# The previous code failed because it was looking for 'Credit_Card_Fraud_Detection.csv'
# but the directory listing showed the actual file name is 'BankChurners.csv'.
df = pd.read_csv(os.path.join(path, 'BankChurners.csv'))

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
print('DataFrame Info:')
df.info()
print('\nDataFrame Description:')
display(df.describe())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [markdown]
# ### Distribution of Target Variable (Attrition_Flag)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the distribution of the target variable 'Attrition_Flag'
plt.figure(figsize=(6, 4))
sns.countplot(x='Attrition_Flag', data=df, palette='viridis', hue='Attrition_Flag', legend=False)
plt.title('Distribution of Attrition Flag')
plt.xlabel('Attrition Flag (0: Existing Customer, 1: Attrited Customer)')
plt.ylabel('Count')
plt.xticks([0, 1], ['Existing Customer', 'Attrited Customer'])
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Create a copy of the dataframe to avoid modifying the original 'df' prematurely
df_encoded = df.copy()

# Identify categorical columns (object type) and apply Label Encoding
for col in df_encoded.select_dtypes(include='object').columns:
    df_encoded[col] = LabelEncoder().fit_transform(df_encoded[col])

plt.figure(figsize=(20, 17))
sns.heatmap(df_encoded.corr(), annot=False, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Features')
plt.show()

# %% [markdown]
# ### Distribution of Customer Age

# %%
# Distribution of Customer_Age
plt.figure(figsize=(10, 6))
sns.histplot(df['Customer_Age'], kde=True, bins=30, palette='viridis')
plt.title('Distribution of Customer Age')
plt.xlabel('Customer Age')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_3747/2965558205.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['Customer_Age'], kde=True, bins=30, palette='viridis')

# %% [markdown]
# ### Customer Age vs. Attrition Flag

# %%
# Customer Age vs. Attrition_Flag
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition_Flag', y='Customer_Age', data=df, palette='viridis')
plt.title('Customer Age Distribution by Attrition Flag')
plt.xlabel('Attrition Flag (0: Existing Customer, 1: Attrited Customer)')
plt.ylabel('Customer Age')
plt.xticks([0, 1], ['Existing Customer', 'Attrited Customer'])
plt.show()
# Out:
# /tmp/ipykernel_3747/202676524.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition_Flag', y='Customer_Age', data=df, palette='viridis')

# %% [markdown]
# ### Distribution of Income Category

# %%
# Distribution of Income_Category
plt.figure(figsize=(12, 6))
sns.countplot(x='Income_Category', data=df, palette='viridis')
plt.title('Distribution of Income Category')
plt.xlabel('Income Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3747/1146843397.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Income_Category', data=df, palette='viridis')

# %% [markdown]
# ### Income Category vs. Attrition Flag

# %%
# Income Category vs. Attrition_Flag
plt.figure(figsize=(12, 6))
sns.countplot(x='Income_Category', hue='Attrition_Flag', data=df, palette='viridis')
plt.title('Income Category Distribution by Attrition Flag')
plt.xlabel('Income Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Attrition Flag', labels=['Existing Customer', 'Attrited Customer'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Months on Book

# %%
# Distribution of Months_on_book
plt.figure(figsize=(10, 6))
sns.histplot(df['Months_on_book'], kde=True, bins=30, palette='viridis')
plt.title('Distribution of Months on Book')
plt.xlabel('Months on Book')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_3747/3948413396.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['Months_on_book'], kde=True, bins=30, palette='viridis')

# %% [markdown]
# ### Months on Book vs. Attrition Flag

# %%
# Months_on_book vs. Attrition_Flag
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition_Flag', y='Months_on_book', data=df, palette='viridis')
plt.title('Months on Book Distribution by Attrition Flag')
plt.xlabel('Attrition Flag (0: Existing Customer, 1: Attrited Customer)')
plt.ylabel('Months on Book')
plt.xticks([0, 1], ['Existing Customer', 'Attrited Customer'])
plt.show()
# Out:
# /tmp/ipykernel_3747/1430029912.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition_Flag', y='Months_on_book', data=df, palette='viridis')

# %% [markdown]
# ### Distribution of Total Transaction Amount

# %%
# Distribution of Total_Trans_Amt
plt.figure(figsize=(10, 6))
sns.histplot(df['Total_Trans_Amt'], kde=True, bins=30, palette='viridis')
plt.title('Distribution of Total Transaction Amount')
plt.xlabel('Total Transaction Amount')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_3747/991555915.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['Total_Trans_Amt'], kde=True, bins=30, palette='viridis')

# %% [markdown]
# ### Total Transaction Amount vs. Attrition Flag

# %%
# Total_Trans_Amt vs. Attrition_Flag
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition_Flag', y='Total_Trans_Amt', data=df, palette='viridis')
plt.title('Total Transaction Amount Distribution by Attrition Flag')
plt.xlabel('Attrition Flag (0: Existing Customer, 1: Attrited Customer)')
plt.ylabel('Total Transaction Amount')
plt.xticks([0, 1], ['Existing Customer', 'Attrited Customer'])
plt.show()
# Out:
# /tmp/ipykernel_3747/2646386946.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition_Flag', y='Total_Trans_Amt', data=df, palette='viridis')

# %% [markdown]
# ### Distribution of Gender

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', data=df, palette='viridis')
plt.title('Distribution of Gender')
plt.xlabel('Gender (0: Female, 1: Male)')
plt.ylabel('Count')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()
# Out:
# /tmp/ipykernel_3747/3141894756.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='viridis')

# %% [markdown]
# ### Gender vs. Attrition Flag

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', hue='Attrition_Flag', data=df, palette='viridis')
plt.title('Gender Distribution by Attrition Flag')
plt.xlabel('Gender (0: Female, 1: Male)')
plt.ylabel('Count')
plt.xticks([0, 1], ['Female', 'Male'])
plt.legend(title='Attrition Flag', labels=['Existing Customer', 'Attrited Customer'])
plt.show()

# %% [markdown]
# ### Distribution of Education Level

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Education_Level', data=df, palette='viridis')
plt.title('Distribution of Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3747/3290119241.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Education_Level', data=df, palette='viridis')

# %% [markdown]
# ### Education Level vs. Attrition Flag

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Education_Level', hue='Attrition_Flag', data=df, palette='viridis')
plt.title('Education Level Distribution by Attrition Flag')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Attrition Flag', labels=['Existing Customer', 'Attrited Customer'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Marital Status

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Marital_Status', data=df, palette='viridis')
plt.title('Distribution of Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3747/3363983452.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Marital_Status', data=df, palette='viridis')

# %% [markdown]
# ### Marital Status vs. Attrition Flag

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Marital_Status', hue='Attrition_Flag', data=df, palette='viridis')
plt.title('Marital Status Distribution by Attrition Flag')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Attrition Flag', labels=['Existing Customer', 'Attrited Customer'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Card Category

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Card_Category', data=df, palette='viridis')
plt.title('Distribution of Card Category')
plt.xlabel('Card Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3747/901814626.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Card_Category', data=df, palette='viridis')

# %% [markdown]
# ### Card Category vs. Attrition Flag

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Card_Category', hue='Attrition_Flag', data=df, palette='viridis')
plt.title('Card Category Distribution by Attrition Flag')
plt.xlabel('Card Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Attrition Flag', labels=['Existing Customer', 'Attrited Customer'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Total Relationship Count

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Total_Relationship_Count', data=df, palette='viridis')
plt.title('Distribution of Total Relationship Count')
plt.xlabel('Total Relationship Count')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3747/4106019069.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Total_Relationship_Count', data=df, palette='viridis')

# %% [markdown]
# ### Total Relationship Count vs. Attrition Flag

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Total_Relationship_Count', hue='Attrition_Flag', data=df, palette='viridis')
plt.title('Total Relationship Count Distribution by Attrition Flag')
plt.xlabel('Total Relationship Count')
plt.ylabel('Count')
plt.legend(title='Attrition Flag', labels=['Existing Customer', 'Attrited Customer'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Dependent Count

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Dependent_count', data=df, palette='viridis')
plt.title('Distribution of Dependent Count')
plt.xlabel('Dependent Count')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3747/994536367.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Dependent_count', data=df, palette='viridis')

# %% [markdown]
# ### Dependent Count vs. Attrition Flag

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Dependent_count', hue='Attrition_Flag', data=df, palette='viridis')
plt.title('Dependent Count Distribution by Attrition Flag')
plt.xlabel('Dependent Count')
plt.ylabel('Count')
plt.legend(title='Attrition Flag', labels=['Existing Customer', 'Attrited Customer'])
plt.tight_layout()
plt.show()

# %%
# Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0      768805383               1            45       1                3
# 1      818770008               1            49       0                5
# 2      713982108               1            51       1                3
# 3      769911858               1            40       0                4
# 4      709106358               1            40       1                3
# ...          ...             ...           ...     ...              ...
# 10122  772366833               1            50       1                2
# 10123  710638233               0            41       1                2
# 10124  716506083               0            44       0                1
# 10125  717406983               0            30       1                2
# 10126  714337233               0            43       0                2
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# ...

# %%
# encoding
cat_cols=df.select_dtypes(include=['object']).columns.tolist()

# %%
cat_cols
# Out:
# []

# %%
df_copy=pd.get_dummies(df,columns=cat_cols,drop_first=True)
df_copy
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0      768805383               1            45       1                3
# 1      818770008               1            49       0                5
# 2      713982108               1            51       1                3
# 3      769911858               1            40       0                4
# 4      709106358               1            40       1                3
# ...          ...             ...           ...     ...              ...
# 10122  772366833               1            50       1                2
# 10123  710638233               0            41       1                2
# 10124  716506083               0            44       0                1
# 10125  717406983               0            30       1                2
# 10126  714337233               0            43       0                2
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df_copy['Attrition_Flag']=le.fit_transform(df['Attrition_Flag'])

# %%
x=df_copy.drop('Attrition_Flag',axis=1)
y=df_copy['Attrition_Flag']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()
# object=class()

# %%
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import classification_report

print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8386
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       327
#            1       0.84      1.00      0.91      1699
#
#     accuracy                           0.84      2026
#    macro avg       0.42      0.50      0.46      2026
# weighted avg       0.70      0.84      0.76      2026
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8385982230997039

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
import joblib
joblib.dump(model,'naive.joblib')
# Out:
# ['naive.joblib']
